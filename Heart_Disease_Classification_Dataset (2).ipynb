# %% [markdown]
# **Cardiovascular illnesses (CVDs)** are the major cause of death worldwide. CVDs include coronary heart disease, cerebrovascular disease, rheumatic heart disease, and other heart and blood vessel problems. According to the World Health Organization, 17.9 million people die each year. Heart attacks and strokes account for more than four out of every five CVD deaths, with one-third of these deaths occurring before the age of 70. A comprehensive database for factors that contribute to a heart attack has been constructed.
#
# The main purpose here is to collect characteristics of Heart Attack or factors that contribute to it.
# The size of the dataset is 1319 samples, which have nine fields, where eight fields are for input fields and one field for an output field. Age, gender(0 for Female, 1 for Male) ,heart rate (impulse), systolic BP (pressurehight), diastolic BP (pressurelow), blood sugar(glucose), CK-MB (kcm), and Test-Troponin (troponin) are representing the input fields, while the output field pertains to the presence of heart attack (class), which is divided into two categories (negative and positive); negative refers to the absence of a heart attack, while positive refers to the presence of a heart attack.

# %%
# Import liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/Heart Attack.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            1319 non-null   int64
#  1   gender         1319 non-null   int64
#  2   impluse        1319 non-null   int64
#  3   pressurehight  1319 non-null   int64
#  4   pressurelow    1319 non-null   int64
#  5   glucose        1319 non-null   float64
#  6   kcm            1319 non-null   float64
#  7   troponin       1319 non-null   float64
#  8   class          1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
df.shape
# Out:
# (1319, 9)

# %%
df.describe()
# Out:
#                age       gender      impluse  pressurehight  pressurelow  \
# count  1319.000000  1319.000000  1319.000000    1319.000000  1319.000000
# mean     56.191812     0.659591    78.336619     127.170584    72.269143
# std      13.647315     0.474027    51.630270      26.122720    14.033924
# min      14.000000     0.000000    20.000000      42.000000    38.000000
# 25%      47.000000     0.000000    64.000000     110.000000    62.000000
# 50%      58.000000     1.000000    74.000000     124.000000    72.000000
# 75%      65.000000     1.000000    85.000000     143.000000    81.000000
# max     103.000000     1.000000  1111.000000     223.000000   154.000000
#
#            glucose          kcm     troponin
# count  1319.000000  1319.000000  1319.000000
# mean    146.634344    15.274306     0.360942
# std      74.923045    46.327083     1.154568
# min      35.000000     0.321000     0.001000
# 25%      98.000000     1.655000     0.006000
# ...

# %%
# checking duplicates
dups = df.duplicated()
print("Number of duplicated rows %d" % (dups.sum()))
df[dups]
# Out:
# Number of duplicated rows 0
# Empty DataFrame
# Columns: [age, gender, impluse, pressurehight, pressurelow, glucose, kcm, troponin, class]
# Index: []

# %%
# Checking Null Values
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# **Univariate Analysis**

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the histogram on the first subplot
sns.histplot(data=df, x='age', kde=True, ax=axes[0])
axes[0].set_xlabel('Age')
axes[0].set_title('Age Distribution')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
sns.boxplot(x='class', y='age', data=df, ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('Age')

# Create a violin plot on the third subplot
sns.violinplot(x='class', y='age', data=df, ax=axes[2])
axes[2].set_title('Violin Plot')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('Age')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the histogram on the first subplot
sns.histplot(data=df, x='impluse', kde=True, ax=axes[0])
axes[0].set_xlabel('impluse')
axes[0].set_title('impluse Distribution')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
sns.boxplot(x='class', y='impluse', data=df, ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('impluse')

# Create a violin plot on the third subplot
sns.violinplot(x='class', y='impluse', data=df, ax=axes[2])
axes[2].set_title('Violin Plot')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('impluse')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the histogram on the first subplot
sns.histplot(data=df, x='pressurehight', kde=True, ax=axes[0])
axes[0].set_xlabel('pressurehight')
axes[0].set_title('pressurehight Distribution')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
sns.boxplot(x='class', y='pressurehight', data=df, ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('pressurehight')

# Create a violin plot on the third subplot
sns.violinplot(x='class', y='pressurehight', data=df, ax=axes[2])
axes[2].set_title('Violin Plot')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('pressurehight')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the histogram on the first subplot
sns.histplot(data=df, x='pressurelow', kde=True, ax=axes[0])
axes[0].set_xlabel('pressurelow')
axes[0].set_title('pressurelow Distribution')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
sns.boxplot(x='class', y='pressurelow', data=df, ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('pressurelow')

# Create a violin plot on the third subplot
sns.violinplot(x='class', y='pressurelow', data=df, ax=axes[2])
axes[2].set_title('Violin Plot')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('pressurelow')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the histogram on the first subplot
sns.histplot(data=df, x='glucose', kde=True, ax=axes[0])
axes[0].set_xlabel('glucose')
axes[0].set_title('glucose Distribution')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
sns.boxplot(x='class', y='glucose', data=df, ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('glucose')

# Create a violin plot on the third subplot
sns.violinplot(x='class', y='glucose', data=df, ax=axes[2])
axes[2].set_title('Violin Plot')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('glucose')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the histogram on the first subplot
sns.histplot(data=df, x='kcm', kde=True, ax=axes[0])
axes[0].set_xlabel('kcm')
axes[0].set_title('kcm Distribution')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
sns.boxplot(x='class', y='kcm', data=df, ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('kcm')

# Create a violin plot on the third subplot
sns.violinplot(x='class', y='kcm', data=df, ax=axes[2])
axes[2].set_title('Violin Plot')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('kcm')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the histogram on the first subplot
sns.histplot(data=df, x='troponin', kde=True, ax=axes[0])
axes[0].set_xlabel('troponin')
axes[0].set_title('troponin Distribution')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
sns.boxplot(x='class', y='troponin', data=df, ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('troponin')

# Create a violin plot on the third subplot
sns.violinplot(x='class', y='troponin', data=df, ax=axes[2])
axes[2].set_title('Violin Plot')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('troponin')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# # Points for class=negative and troponin=10 must be check

# %%
d1 = df['class']=='negative'
d11 = df[d1]

d2 = d11.troponin > 9
d22 = d11[d2]

d22
# Out:
#     age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 29   63       1       66            135           55    166.0  0.493
#
#     troponin     class
# 29      10.0  negative

# %%
df.drop(index=29, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
#The Shapiro-Wilk test is a statistical test used to assess whether a dataset follows a normal distribution.
#In the context of this test, the null hypothesis (H0) and alternative hypothesis (Ha) can be stated as follows:

#Null Hypothesis (H0):
#The null hypothesis for the Shapiro-Wilk test is that the data in the sample follows a normal distribution.

#Alternative Hypothesis (Ha):
#The alternative hypothesis is that the data in the sample does not follow a normal distribution.


from scipy.stats import shapiro
shapiro_test_statistic, shapiro_p_value = shapiro(df['age'])
print(f'Shapiro-Wilk Test: W = {shapiro_test_statistic}, p-value = {shapiro_p_value}')

#"Based on the results of the Shapiro-Wilk test (p, 0.00000049<0.05,Alpha),
#we reject the null hypothesis and conclude that the data is not normally distributed."
# Out:
# Shapiro-Wilk Test: W = 0.9913412928581238, p-value = 5.283334871819534e-07

# %%
import scipy.stats as stats

# Separate the df into "positive" and "negative" groups based on the "class" variable
positive_kcm = df[df['class'] == 'positive']['kcm']
negative_kcm = df[df['class'] == 'negative']['kcm']

# Perform a t-test
t_stat, p_value = stats.ttest_ind(positive_kcm, negative_kcm)

# Set your significance level (alpha)
alpha = 0.05

print("T-Statistic:", t_stat)
print("P-Value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: kcm is a significant predictor of a heart attack.")
else:
    print("Fail to reject the null hypothesis: kcm is not a significant predictor of a heart attack.")
# Out:
# T-Statistic: 8.085813597169937
# P-Value: 1.3883533633698384e-15
# Reject the null hypothesis: kcm is a significant predictor of a heart attack.

# %%
skewness=df.skew()
skewness
# Out:
# age              -0.238153
# gender           -0.673149
# impluse          18.241469
# pressurehight     0.685720
# pressurelow       0.488474
# glucose           1.933466
# kcm               4.976087
# troponin          5.829524
# dtype: float64

# %%
# Check how many numbers of male & female
sns.countplot(data =df,x ='gender')
plt.xlabel('Gender')
plt.title('Count of Males and Females')
# Out:
# Text(0.5, 1.0, 'Count of Males and Females')

# %%
gender_counts = df['gender'].value_counts()
total_count = len(df)

# Calculate the percentage of males and females
percentage_male = (gender_counts[1] / total_count) * 100
percentage_female = (gender_counts[0] / total_count) * 100

# Create data for the pie chart
labels = ['Male', 'Female']
sizes = [percentage_male, percentage_female]
colors = ['lightblue', 'lightcoral']
explode = (0.1, 0)  # Explode the 'Male' slice

# Create a pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Percentage of Males and Females')
plt.show()

# %%
sns.barplot(data = df,x='gender',y='age',ci =None,hue = 'class')
# Set the style with grid lines
sns.set_style("whitegrid")

plt.show()
# Male group is younger than female group
# Males(56) gets heart attacks in less age than female(61)

# %%
sns.barplot(data = df,x='gender',y='kcm',ci = None,hue ='class')
# Out:
# <Axes: xlabel='gender', ylabel='kcm'>

# %%
sns.lineplot(data = df,x='age',y='kcm',ci = None,hue ='class')
# Out:
# <Axes: xlabel='age', ylabel='kcm'>

# %%
sns.barplot(data = df,x='gender',y='troponin',ci = None,hue ='class')
# Out:
# <Axes: xlabel='gender', ylabel='troponin'>

# %%
sns.lineplot(data = df,x='age',y='troponin',ci = None,hue ='class')
# Out:
# <Axes: xlabel='age', ylabel='troponin'>

# %%
# Calculate the correlation matrix
corr_matrix = df.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(12, 7))

# Create a heatmap for the lower half of the correlation matrix
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='Blues', mask=mask)

# Show the plot
plt.show()

# %%
sns.pairplot(df)

# %%
# Apply log transformation to the columns with skewed data
df['glucose'] = np.log1p(df['glucose'])
df['impluse'] = np.log1p(df['impluse'])
df['kcm'] = np.log1p(df['kcm'])
df['troponin'] = np.log1p(df['troponin'])

# %% [markdown]
# # Assumption of Decision Tree & Random Forest
#  1) Scaling is not required
#
#  2) Data is not required to be ditributed normally
#
#  3) Non-linearity: Decision Trees assume that the underlying relationship between features and the target variable is non-linear.They can capture complex, non-linear patterns in the data.
#  4)RF is robust to outliers
#
# # Limitation of DT & RF
#  1) Overfitting on Noisy Data
#
#  2) Biased Towards Majority Classes
#
#  3) Not Suitable for High-Dimensional Data

# %%
#After this feature engineering step, your data will be ready for training a Random Forest model,
# where the "Class" column will serve as the target variable with 0 for "negative" and 1 for "positive."


from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['class'] = label_encoder.fit_transform(df['class'])

# %%
sns.countplot(data =df,x =df['class'])
# Yes, data is imbalanced,,,
# Ensemble Methods: Ensemble methods like Random Forest are less sensitive to class imbalance compared
# to some other algorithms. The combination of multiple decision trees can help
# mitigate the impact of class imbalance to some extent.
# where the "Class" column will serve as the target variable with 0 for "negative" and 1 for "positive."
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# Extracting the target column into separate vectors for training set and test set
X = df.drop('class',axis =1)

y = df.pop('class')

X.head()
# Out:
#    age  gender   impluse  pressurehight  pressurelow   glucose       kcm  \
# 0   64       1  4.204693            160           83  5.081404  1.029619
# 1   21       1  4.553877             98           46  5.693732  2.047693
# 2   55       1  4.174387            160           77  5.602119  1.095273
# 3   64       1  4.262680            120           55  5.602119  2.699346
# 4   55       1  4.174387            112           65  5.707110  0.732368
#
#    troponin
# 0  0.011929
# 1  0.722706
# 2  0.002996
# 3  0.115113
# 4  0.002996

# %%
#splitting data into train and test set

from sklearn.model_selection import train_test_split

X_train, X_test, train_labels, test_labels = train_test_split(X,y,test_size =0.3,random_state =14)

# %%
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('train_labels',train_labels.shape)
print('test_labels',test_labels.shape)
print('Total Observations',923+396)
# Out:
# X_train (922, 8)
# X_test (396, 8)
# train_labels (922,)
# test_labels (396,)
# Total Observations 1319

# %%
# Building Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model=DecisionTreeClassifier(criterion= 'gini',random_state= 1,)

# %%
dt_model.fit(X_train,train_labels)
# Out:
# DecisionTreeClassifier(random_state=1)

# %% [markdown]
# # Predictions and Evaluation of Decision Tree

# %%
ytrain_predict = dt_model.predict(X_train)
ytest_predict = dt_model.predict(X_test)

# %% [markdown]
# # Print Feature Importances

# %%
x=pd.DataFrame(dt_model.feature_importances_*100,index=X_train.columns).sort_values(by=0,ascending=False)
plt.figure(figsize=(12,7))
sns.barplot(x=x.index, y=x.iloc[:, 0], palette='rainbow')
plt.ylabel('Feature Name')
plt.xlabel('Feature Importance in %')
plt.title('Feature Importance Plot')
plt.show()

# %% [markdown]
# # Evaluating model performance with confusion matrix

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %% [markdown]
# # Evaluating model performance on the training data

# %%
# Get the confusion matrix on the train data
confusion_matrix(train_labels,ytrain_predict)
sns.heatmap(confusion_matrix(train_labels,ytrain_predict),annot=True, fmt='d',cbar=False, cmap='rainbow')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(train_labels,ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       376
#            1       1.00      1.00      1.00       546
#
#     accuracy                           1.00       922
#    macro avg       1.00      1.00      1.00       922
# weighted avg       1.00      1.00      1.00       922

# %%
from sklearn.metrics import roc_curve,roc_auc_score
dt_fpr, dt_tpr,_=roc_curve(train_labels,dt_model.predict_proba(X_train)[:,1])
plt.figure(figsize=(12,7))
plt.plot(dt_fpr,dt_tpr, marker='x', label='Decision Tree')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(train_labels,dt_model.predict_proba(X_train)[:,1]))
# Out:
# Area under Curve is 1.0

# %% [markdown]
# # Evaluating model performance on the test data

# %%
# Get the confusion matrix on the test data
confusion_matrix(test_labels,ytest_predict)
sns.heatmap(confusion_matrix(test_labels,ytest_predict),annot=True, fmt='d',cbar=False, cmap='rainbow')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(test_labels,ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       132
#            1       0.98      0.99      0.98       264
#
#     accuracy                           0.98       396
#    macro avg       0.98      0.97      0.98       396
# weighted avg       0.98      0.98      0.98       396

# %%
DTs_score=dt_model.score(X_test,test_labels)
DTs_score
# Out:
# 0.9797979797979798

# %%
dt_fpr, dt_tpr,_=roc_curve(test_labels,dt_model.predict_proba(X_test)[:,1])
plt.figure(figsize=(12,7))
plt.plot(dt_fpr,dt_tpr, marker='x', label='Decision Tree')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(test_labels,dt_model.predict_proba(X_test)[:,1]))
# Out:
# Area under Curve is 0.9734848484848485

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Ensemble RandomForest Classifier-with out treating outliers

# %%
#Build a RandomForestCassifier wit n_estimators 100, max_features 6, andfit it on the training data
rfcl = RandomForestClassifier(n_estimators = 100,max_features=6,random_state=0)
rfcl = rfcl.fit(X_train, train_labels)

# %% [markdown]
# #Predicting Train and Test data with the RF Model

# %%
ytrain_pred = rfcl.predict(X_train)
ytest_pred = rfcl.predict(X_test)

# %% [markdown]
# # Train Accuracy

# %%
rfcl.score(X_train,train_labels)
# Out:
# 1.0

# %% [markdown]
# # Evaluating model performance on the training data

# %%
# Get the confusion matrix on the train data
confusion_matrix(train_labels,ytrain_pred)
sns.heatmap(confusion_matrix(train_labels,ytrain_pred),annot=True, fmt='d',cbar=False, cmap='rainbow')
plt.xlabel('predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(train_labels,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       376
#            1       1.00      1.00      1.00       546
#
#     accuracy                           1.00       922
#    macro avg       1.00      1.00      1.00       922
# weighted avg       1.00      1.00      1.00       922

# %%
from sklearn.metrics import roc_curve,roc_auc_score
rf_fpr, rf_tpr,_=roc_curve(train_labels,rfcl.predict_proba(X_train)[:,1])
plt.figure(figsize=(12,7))
plt.plot(rf_fpr,rf_tpr, marker='x', label='Random Forest')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(train_labels,rfcl.predict_proba(X_train)[:,1]))
# Out:
# Area under Curve is 1.0

# %% [markdown]
# #Evaluating model performance on the test data

# %%
confusion_matrix(test_labels,ytest_pred)
sns.heatmap(confusion_matrix(test_labels,ytest_pred),annot=True, fmt='d',cbar=False, cmap='rainbow')
plt.xlabel('predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(test_labels,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       132
#            1       0.99      0.98      0.98       264
#
#     accuracy                           0.98       396
#    macro avg       0.98      0.98      0.98       396
# weighted avg       0.98      0.98      0.98       396

# %% [markdown]
# # Test Accuracy

# %%
RF_score = rfcl.score(X_test,test_labels)
RF_score
# Out:
# 0.9797979797979798

# %%
#from sklearn.metrics import roc_curve,roc_auc_score
rf_fpr, rf_tpr,_=roc_curve(test_labels,rfcl.predict_proba(X_test)[:,1])
plt.figure(figsize=(12,7))
plt.plot(rf_fpr,rf_tpr, marker='x', label='Random Forest')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(test_labels,rfcl.predict_proba(X_test)[:,1]))
# Out:
# Area under Curve is 0.9984934573002755

# %% [markdown]
# # Ensemble RandomForest Classifier-with treating outliers

# %% [markdown]
# # Treating the Outliers

# %%
# Complete the function to calculate lower_range and upper_range
def treat_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
 df_outlier = df.copy()

# %%
for feature in df_outlier[['age', 'impluse', 'pressurehight', 'pressurelow', 'glucose','kcm','troponin']]:
    lr,ur=treat_outlier(df_outlier[feature])
    df_outlier[feature]=np.where(df_outlier[feature]>ur,ur,df_outlier[feature])
    df_outlier[feature]=np.where(df_outlier[feature]<lr,lr,df_outlier[feature])

# %%
plt.figure(figsize=(15,15))
df_outlier[['age', 'impluse', 'pressurehight', 'pressurelow', 'glucose','kcm','troponin']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Capture the target column into separate vectors for training set and test set

# %%
# Train data set
X1 = df_outlier

# %% [markdown]
# # Splitting data into training and test set

# %%
X_train, X_test, train_labels, test_labels = train_test_split(X1, y, test_size=.30, random_state=1)

# %% [markdown]
# # KNN

# %% [markdown]
# # Assumption:
# Local Smoothness: KNN assumes that similar data points are likely to have similar labels or values. This is why it relies on proximity to make predictions. It assumes that the decision boundary is not highly irregular or complex.
#
# K-Value Selection: The choice of the value of "k" (the number of nearest neighbors to consider) is important. A small value of k might lead to overfitting, while a large value of k might lead to underfitting. Therefore, selecting an appropriate k value is crucial.
#
# 1)KNN uses distance metrics (e.g., Euclidean distance) to determine the nearest neighbors.So it scaling is must.
#
# 2)Outliers can significantly affect the performance of KNN.

# %%
from scipy.stats import zscore

# %%
df_outlier[['age', 'impluse', 'pressurehight', 'pressurelow', 'glucose','kcm','troponin']]=df_outlier[['age', 'impluse', 'pressurehight', 'pressurelow', 'glucose','kcm','troponin']].apply(zscore)

# %%
df_outlier.head()
# Out:
#         age  gender   impluse  pressurehight  pressurelow   glucose       kcm  \
# 0  0.577453       1 -0.638771       1.325572     0.787094  0.454831 -0.671711
# 1 -2.594036       1  1.186664      -1.151569    -1.909130  1.957408  0.574684
# 2 -0.086347       1 -0.797198       1.325572     0.349869  1.732600 -0.591333
# 3  0.577453       1 -0.335630      -0.272584    -1.253291  1.732600  1.372482
# 4 -0.086347       1 -0.797198      -0.592215    -0.524582  1.990236 -1.035627
#
#    troponin
# 0 -0.591542
# 1  1.872378
# 2 -0.711786
# 3  0.797369
# 4 -0.711786

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN_model=KNeighborsClassifier()
KNN_model.fit(X_train,train_labels)
# Out:
# KNeighborsClassifier()

# %%
ytrain_predict = KNN_model.predict(X_train)
ytest_predict = KNN_model.predict(X_test)

# %%
## Performance Matrix on train data set
from sklearn import metrics
train_labels_predict = KNN_model.predict(X_train)
model_score = KNN_model.score(X_train, train_labels)
print(model_score)
print(metrics.confusion_matrix(train_labels, train_labels_predict))
print(metrics.classification_report(train_labels, train_labels_predict))
# Out:
# 0.745119305856833
# [[244 138]
#  [ 97 443]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.64      0.67       382
#            1       0.76      0.82      0.79       540
#
#     accuracy                           0.75       922
#    macro avg       0.74      0.73      0.73       922
# weighted avg       0.74      0.75      0.74       922

# %%
## Performance Matrix on test data set
from sklearn import metrics
test_labels_predict = KNN_model.predict(X_test)
model_score = KNN_model.score(X_test, test_labels)
print(model_score)
print(metrics.confusion_matrix(test_labels, test_labels_predict))
print(metrics.classification_report(test_labels, test_labels_predict))
# Out:
# 0.5681818181818182
# [[ 57  69]
#  [102 168]]
#               precision    recall  f1-score   support
#
#            0       0.36      0.45      0.40       126
#            1       0.71      0.62      0.66       270
#
#     accuracy                           0.57       396
#    macro avg       0.53      0.54      0.53       396
# weighted avg       0.60      0.57      0.58       396

# %%
0.745119305856833-0.5681818181818182
# Out:
# 0.17693748767501472

# %% [markdown]
# As the difference between train and test accuracies is 17.69 % which is more than 10%(Industry standard).

# %% [markdown]
# Run the KNN with no of neighbours to be 1,3,5..19 and *Find the optimal number of neighbours from K=1,3,5,7....19 using the Mis classification error
#
# Hint: Misclassification error (MCE) = 1 - Test accuracy score. Calculated MCE for each model with neighbours = 1,3,5...19 and find the model with lowest MCE

# %%
# empty list that will hold accuracy scores
ac_scores = []

# perform accuracy metrics for values from 1,3,5....19
for k in range(1,20,2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, train_labels)
    # evaluate test accuracy
    scores = knn.score(X_test, test_labels)
    ac_scores.append(scores)

# changing to misclassification error
MCE = [1 - x for x in ac_scores]
MCE
# Out:
# [0.43181818181818177,
#  0.43181818181818177,
#  0.43181818181818177,
#  0.4217171717171717,
#  0.41414141414141414,
#  0.41666666666666663,
#  0.4242424242424242,
#  0.4015151515151515,
#  0.3762626262626263,
#  0.38131313131313127]

# %%
# plot misclassification error vs k
plt.plot(range(1,20,2), MCE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %% [markdown]
# lets check train and test for K=17 with other evaluation metrics

# %%
KNN_model=KNeighborsClassifier(n_neighbors=17)
KNN_model.fit(X_train,train_labels)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
ytrain_predict = KNN_model.predict(X_train)
ytest_predict = KNN_model.predict(X_test)

# %%
## Performance Matrix on train data set
from sklearn import metrics
train_labels_predict = KNN_model.predict(X_train)
model_score = KNN_model.score(X_train, train_labels)
print(model_score)
print(metrics.confusion_matrix(train_labels, train_labels_predict))
print(metrics.classification_report(train_labels, train_labels_predict))
# Out:
# 0.6605206073752712
# [[176 206]
#  [107 433]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.46      0.53       382
#            1       0.68      0.80      0.73       540
#
#     accuracy                           0.66       922
#    macro avg       0.65      0.63      0.63       922
# weighted avg       0.65      0.66      0.65       922

# %%
## Performance Matrix on test data set
from sklearn import metrics
test_labels_predict = KNN_model.predict(X_test)
model_score = KNN_model.score(X_test, test_labels)
print(model_score)
print(metrics.confusion_matrix(test_labels, test_labels_predict))
print(metrics.classification_report(test_labels, test_labels_predict))
# Out:
# 0.6237373737373737
# [[ 62  64]
#  [ 85 185]]
#               precision    recall  f1-score   support
#
#            0       0.42      0.49      0.45       126
#            1       0.74      0.69      0.71       270
#
#     accuracy                           0.62       396
#    macro avg       0.58      0.59      0.58       396
# weighted avg       0.64      0.62      0.63       396

# %%
knn_score = model_score

# %% [markdown]
# # Gaussian Naive Bayes
# Gaussian Naive Bayes is a probabilistic machine learning algorithm used for classification tasks. It makes its predictions based on the assumption that the features are continuous and follow a Gaussian (normal) distribution. Here are the main assumptions associated with Gaussian Naive Bayes:
#
# 1)Feature Independence:
#
# 2)Continuous Features:
#
# 3)Small Sample Size: Gaussian Naive Bayes can perform poorly when the dataset is small or the number of examples in each class is very small.
#
# 4)No Collinearity:
#
# Summary:
# It's important to note that while these are the main assumptions associated with Gaussian Naive Bayes, in practice, the algorithm can be quite robust and work well for many classification tasks, especially when the features have a roughly Gaussian distribution and the independence assumption is not strongly violated. However, it's a good practice to evaluate different algorithms and preprocessing techniques to determine the best approach for your specific dataset and problem.

# %%
from sklearn.naive_bayes import GaussianNB
NB_model = GaussianNB()
NB_model.fit(X_train,train_labels)
# Out:
# GaussianNB()

# %%
y_train_predict = NB_model.predict(X_train)
model_score = NB_model.score(X_train, train_labels)                      ## Accuracy
print(model_score)
print(metrics.confusion_matrix(train_labels, y_train_predict))
print(metrics.classification_report(train_labels, y_train_predict))
# Out:
# 0.9457700650759219
# [[377   5]
#  [ 45 495]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       382
#            1       0.99      0.92      0.95       540
#
#     accuracy                           0.95       922
#    macro avg       0.94      0.95      0.94       922
# weighted avg       0.95      0.95      0.95       922

# %%
## Performance Matrix on test data set
y_test_predict = NB_model.predict(X_test)
model_score = NB_model.score(X_test, test_labels)                    ## Accuracy
print(model_score)
print(metrics.confusion_matrix(test_labels, y_test_predict))         ## confusion_matrix
print(metrics.classification_report(test_labels, y_test_predict))
# Out:
# 0.9444444444444444
# [[124   2]
#  [ 20 250]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       126
#            1       0.99      0.93      0.96       270
#
#     accuracy                           0.94       396
#    macro avg       0.93      0.96      0.94       396
# weighted avg       0.95      0.94      0.95       396

# %%
Naive_Score = model_score

# %% [markdown]
# **Looking at Recalls, Training accuracy and Test accuracy. Model seems to be performing well

# %% [markdown]
# ## Conclusion :
#
# ---

# %%
result = pd.DataFrame({
    'Algorithms': ['RF', 'Naive','knn'],
    'Accuracy' : [ RF_score,Naive_Score, knn_score]
})

result
# Out:
#   Algorithms  Accuracy
# 0         RF  0.979798
# 1      Naive  0.944444
# 2        knn  0.623737
